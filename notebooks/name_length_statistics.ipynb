# %%
from src import config
import pandas as pd
import os

# %%
names_csv = pd.read_csv(os.path.join("..",config.RAW_NAMES_FILE_PATH))

# %%
names_csv
# Out:
#                                         alternative_names classification  \
# 0       AILINE|ALEINE|ALIINE|ALINE|ALINER|ALINHE|ALINN...              F
# 1                                              ARAAO|ARAO              M
# 2                            AHARON|AROM|ARON|ARYON|HARON              M
# 3                                 ADA|ADAH|ADAR|ADHA|HADA              F
# 4                                                     NaN              M
# ...                                                   ...            ...
# 100782                                           MACILEIA              F
# 100783  GELINE|GILEINE|GLEINE|GLEINER|GLEYNE|JAELINE|J...              F
# 100784                                  DEMILTOM|DEMILTON              M
# 100785  ALIVIA|ELIVIA|EULIVIA|HOLIVIA|LEIVIA|LIIVIA|LI...              F
# 100786                                             FABSON              M
#
#        first_name  frequency_female  frequency_male  frequency_total  \
# ...

# %%
names_csv.columns
# Out:
# Index(['alternative_names', 'classification', 'first_name', 'frequency_female',
#        'frequency_male', 'frequency_total', 'frequency_group', 'group_name',
#        'ratio'],
#       dtype='object')

# %%
names_csv['len_name'] = names_csv['first_name'].str.len()

# %%
names_csv['len_name'].describe()
# Out:
# count    100787.000000
# mean          7.022810
# std           1.555757
# min           3.000000
# 25%           6.000000
# 50%           7.000000
# 75%           8.000000
# max          14.000000
# Name: len_name, dtype: float64
